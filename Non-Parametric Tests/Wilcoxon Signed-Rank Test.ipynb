# %% [markdown]
# # **Wilcoxon Signed-Rank Test**

# %% [markdown]
# The Wilcoxon Signed-Rank Test is a non-parametric statistical test used to determine whether there is a significant difference between the paired observations. It is the non-parametric equivalent of the paired sample t-test and is used for comparing two related samples or measurements taken from the same group.
#
# **Why We Use It:**
# - The Wilcoxon Signed-Rank Test is used when the data are paired and do not meet the assumptions required for the paired t-test (e.g., normality).
#
# - It is useful for assessing whether the median of the differences between the pairs is zero, which means there is no difference between the two conditions being compared.
#
# - This test is particularly appropriate for small sample sizes and data with outliers or skewed distributions.
#
# **When to Use It:**
# - When comparing two related or paired samples.
#
# - When the data are ordinal, interval, or ratio but do not meet the assumptions of normality.
#
# - It is commonly used in before-and-after experiments or matched-pair studies.

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### Generating Dataset Code

# %%
# import numpy as np
# import pandas as pd

# np.random.seed(42)

# students = 30  

# before_training_scores = np.random.randint(40, 71, size=students)

# after_training_scores = before_training_scores + np.random.randint(3, 12, size=students)

# after_training_scores = after_training_scores.astype(np.float64) + np.random.normal(0, 2, students)

# data = pd.DataFrame({
#     'Student': [f'Student {i+1}' for i in range(students)],
#     'Before Training': before_training_scores,
#     'After Training': after_training_scores
# })

# data.to_csv('C:/Github Repository/Advanced-Statistical-Methods-for-AB-and-Hypothesis-Testing-Methods-of-Experimentations/datasets/Wilcoxon Signed-Rank Test/students_scores.csv', index=False)

# %% [markdown]
# ### Loading Dataset

# %%
import pandas as pd

data = pd.read_csv('C:/Github Repository/Advanced-Statistical-Methods-for-AB-and-Hypothesis-Testing-Methods-of-Experimentations/datasets/Wilcoxon Signed-Rank Test/students_scores.csv')

# %%
data.head()
# Out:
#      Student  Before Training  After Training
# 0  Student 1               46       48.106517
# 1  Student 2               59       70.048483
# 2  Student 3               68       79.646000
# 3  Student 4               54       54.213166
# 4  Student 5               50       50.643332

# %% [markdown]
# ### Dataset Summary

# %% [markdown]
# - Number of Students: 30
#
# - Before Training Scores: Randomly generated integer scores between 40 and 70, representing test scores before training.
#
# - After Training Scores: Scores derived by adding a slight improvement (random integers between 3 and 12) to the original scores, with added random noise (normally distributed) to simulate variability.

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### Histogram of Before and After Training Scores

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
plt.hist(before_training_scores, bins=10, alpha=0.7, label='Before Training', color='blue', edgecolor='black')
plt.hist(after_training_scores, bins=10, alpha=0.7, label='After Training', color='green', edgecolor='black')
plt.title('Distribution of Before and After Training Scores')
plt.xlabel('Test Scores')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Line plot for individual students (before and after)

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(students), before_training_scores, color='blue', marker='o', label='Before Training', linestyle='-', linewidth=2)
plt.plot(range(students), after_training_scores, color='green', marker='o', label='After Training', linestyle='-', linewidth=2)
plt.title('Before vs After Training Test Scores for Each Student (Line Plot)')
plt.ylabel('Test Scores')
plt.xlabel('Students')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Difference between Before and After Training scores

# %%
differences = after_training_scores - before_training_scores

plt.figure(figsize=(10, 6))
plt.bar(range(students), differences, color='purple', edgecolor='black')
plt.title('Difference Between Before and After Training Test Scores')
plt.ylabel('Score Difference (After - Before)')
plt.xlabel('Students')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Wilcoxon Signed-Rank Test

# %%
from scipy import stats

stat, p_value = stats.wilcoxon(before_training_scores, after_training_scores)

# Print the test statistic and p-value
print(f"Test Statistic: {stat}")
print(f"P-value: {p_value}")

# Interpret the result
if p_value < 0.05:
    print("Reject the null hypothesis: There is a significant difference in scores before and after training.")
else:
    print("Fail to reject the null hypothesis: No significant difference in scores.")
# Out:
# Test Statistic: 0.0
# P-value: 1.862645149230957e-09
# Reject the null hypothesis: There is a significant difference in scores before and after training.

# %% [markdown]
# **Interpretation:**
#
# Since the p-value is much smaller than the significance level (α = 0.05), we reject the null hypothesis. There is a significant difference in the test scores before and after the training, indicating that the training had an impact on the students' performance.
