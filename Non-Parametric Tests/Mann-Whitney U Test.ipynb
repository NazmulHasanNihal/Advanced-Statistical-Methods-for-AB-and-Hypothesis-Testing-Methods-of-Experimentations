# %% [markdown]
# # **Mann-Whitney U Test (Non-parametric T-test)**

# %% [markdown]
# The Mann-Whitney U test is a non-parametric test used to determine whether there is a difference between two independent groups on a continuous or ordinal variable. It is often used as an alternative to the independent t-test when the data is not normally distributed or when the assumption of homogeneity of variance is violated.
#
# **Why to use it ?**
#
# - **Non-parametric nature:** Unlike the t-test, it does not assume that the data follows a normal distribution, making it ideal for non-normally distributed data.
#
# - **Ordinal or continuous data:** It can be used on ordinal data or when the data cannot be assumed to be normally distributed.
#
# - **Comparing two independent groups:** It is particularly useful when comparing two groups that are independent of each other.
#
# **When to use it**
#
# - When we want to compare two independent groups but cannot assume that the data follows a normal distribution.
#
# - When the data is ordinal (e.g., rankings) or continuous but non-normal.
#
# - When sample sizes are small or unequal between the two groups.
#
# - When the assumption of equal variances in the groups (required for the independent t-test) is not met.

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### Generating Dataset Code

# %%
# import numpy as np
# import pandas as pd

# # Set random seed for reproducibility
# np.random.seed(42)

# # Generate data for Class A and Class B
# class_a_scores = np.random.normal(loc=75, scale=10, size=30)
# class_b_scores = np.random.normal(loc=80, scale=12, size=30)
# class_a_study_hours = np.random.normal(loc=5, scale=1.5, size=30)
# class_b_study_hours = np.random.normal(loc=6, scale=1.8, size=30)
# class_a_participation = np.random.normal(loc=8, scale=2, size=30)
# class_b_participation = np.random.normal(loc=8.5, scale=2.2, size=30)

# # Create a DataFrame
# data = pd.DataFrame({
#     'Class A Scores': class_a_scores,
#     'Class B Scores': class_b_scores,
#     'Class A Study Hours': class_a_study_hours,
#     'Class B Study Hours': class_b_study_hours,
#     'Class A Participation': class_a_participation,
#     'Class B Participation': class_b_participation
# })

# data.to_csv('C:/Github Repository/Advanced-Statistical-Methods-for-AB-and-Hypothesis-Testing-Methods-of-Experimentations/datasets/Mann-Whitney U Test/Class_Performance.csv', index=False)

# %% [markdown]
# ### Loading Dataset

# %%
import pandas as pd

data = pd.read_csv('C:/Github Repository/Advanced-Statistical-Methods-for-AB-and-Hypothesis-Testing-Methods-of-Experimentations/datasets/Mann-Whitney U Test/Class_Performance.csv')

# %%
data.head()
# Out:
#    Class A Scores  Class B Scores  Class A Study Hours  Class B Study Hours  \
# 0       79.967142       72.779521             4.281239             6.174740
# 1       73.617357      102.227338             4.721512             7.743561
# 2       81.476885       79.838033             3.340498             4.736304
# 3       90.230299       67.307469             3.205690             5.410208
# 4       72.658466       89.870539             6.218789             5.294205
#
#    Class A Participation  Class B Participation
# 0               9.582064               9.051084
# 1               6.181225               9.262186
# 2              10.805589               7.003946
# 3               5.196298               9.010958
# 4               9.173714               9.144759

# %% [markdown]
# This dataset includes test scores, study hours, and participation scores for two groups of students (Class A and Class B), with 30 observations each.

# %% [markdown]
# ## Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns


plt.figure(figsize=(12, 10))

# Boxplot for Class A and Class B scores
plt.subplot(2, 2, 1)
plt.boxplot([data['Class A Scores'], data['Class B Scores']], labels=['Class A Scores', 'Class B Scores'])
plt.title('Class A vs Class B Scores')
plt.ylabel('Scores')

# Boxplot for Class A and Class B study hours
plt.subplot(2, 2, 2)
plt.boxplot([data['Class A Study Hours'], data['Class B Study Hours']], labels=['Class A Study Hours', 'Class B Study Hours'])
plt.title('Class A vs Class B Study Hours')
plt.ylabel('Study Hours')

# Boxplot for Class A and Class B participation
plt.subplot(2, 2, 3)
plt.boxplot([data['Class A Participation'], data['Class B Participation']], labels=['Class A Participation', 'Class B Participation'])
plt.title('Class A vs Class B Participation')
plt.ylabel('Participation Score')

# Visualizing the distribution of scores for both classes
plt.subplot(2, 2, 4)
plt.hist(data['Class A Scores'], alpha=0.5, label='Class A Scores', bins=10)
plt.hist(data['Class B Scores'], alpha=0.5, label='Class B Scores', bins=10)
plt.title('Distribution of Class A and Class B Scores')
plt.xlabel('Scores')
plt.ylabel('Frequency')
plt.legend()
# Out:
# C:\Users\NIHAL\AppData\Local\Temp\ipykernel_1636\390124210.py:9: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([data['Class A Scores'], data['Class B Scores']], labels=['Class A Scores', 'Class B Scores'])
# C:\Users\NIHAL\AppData\Local\Temp\ipykernel_1636\390124210.py:15: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([data['Class A Study Hours'], data['Class B Study Hours']], labels=['Class A Study Hours', 'Class B Study Hours'])
# C:\Users\NIHAL\AppData\Local\Temp\ipykernel_1636\390124210.py:21: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
# ...

# %% [markdown]
# ## Mann-Whitney U test

# %%
from scipy import stats

stat, p_value = stats.mannwhitneyu(data['Class A Scores'], data['Class B Scores'], alternative='two-sided')
print(f"U-statistic: {stat}, p-value: {p_value}")
if p_value < 0.05:
    print("Reject the null hypothesis: There is a significant difference between Class A and Class B scores.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference between Class A and Class B scores.")
# Out:
# U-statistic: 310.0, p-value: 0.03916706803882588
# Reject the null hypothesis: There is a significant difference between Class A and Class B scores.

# %% [markdown]
# **Interpretation:**
#
# - U Statistic: 310.0
# - P-value: 0.0392 (rounded)
#
# **Since the p-value < 0.05, we reject the null hypothesis, indicating that there is a statistically significant difference in test scores between Class A and Class B.**
